# %%
# Problem 1: Collect Patient Information

print("=" * 45)
print(" SMART BMI & HEALTH RISK ANALYZER ")
print("=" * 45)

name = input("Enter Patient Name: ")
age = int(input("Enter Age (Years): "))
weight = float(input("Enter Weight (kg): "))
height = float(input("Enter Height (m): "))
# Out:
# =============================================
#  SMART BMI & HEALTH RISK ANALYZER
# =============================================
# Enter Patient Name: hamza
# Enter Age (Years): 21
# Enter Weight (kg): 60
# Enter Height (m): 2

# %%
# Problem 2: Calculate BMI

# BMI = Weight / (Height × Height)

bmi = weight / (height * height)

print(f"Calculated BMI : {bmi:.2f}")
# Out:
# Calculated BMI : 15.00

# %%
# Problem 3: BMI Category and Health Risk

if bmi < 18.5:
    category = "Underweight"
elif bmi < 25:
    category = "Normal Weight"
elif bmi < 30:
    category = "Overweight"
else:
    category = "Obese"

# Health Risk

if bmi > 30 and age > 40:
    health_risk = "High Health Risk"
else:
    health_risk = "Normal Risk"

print(f"BMI Category : {category}")
print(f"Health Risk : {health_risk}")
# Out:
# BMI Category : Underweight
# Health Risk : Normal Risk

# %%
# Problem 4: Generate Health Report

print("\n" + "=" * 45)
print("        HEALTH REPORT")
print("=" * 45)
print(f"Patient Name   : {name}")
print(f"Age            : {age} Years")
print(f"Weight         : {weight} kg")
print(f"Height         : {height} m")
print(f"Calculated BMI : {bmi:.2f}")
print(f"BMI Category   : {category}")
print(f"Health Risk    : {health_risk}")

# Health Recommendation

if category == "Underweight":
    advice = "Increase calorie intake and consult a nutritionist."
elif category == "Normal Weight":
    advice = "Maintain your current healthy lifestyle."
elif category == "Overweight":
    advice = "Increase physical activity and improve diet."
else:
    advice = "Consult a healthcare professional and follow a weight management plan."

print("\nHealth Recommendation")
print(advice)
print("=" * 45)
print("Thank you for using Smart BMI & Health Risk Analyzer")
print("=" * 45)
# Out:
# =============================================
#         HEALTH REPORT
# =============================================
# Patient Name   : hamza
# Age            : 21 Years
# Weight         : 60.0 kg
# Height         : 2.0 m
# Calculated BMI : 15.00
# BMI Category   : Underweight
# Health Risk    : Normal Risk
#
# Health Recommendation
# Increase calorie intake and consult a nutritionist.
# =============================================
# Thank you for using Smart BMI & Health Risk Analyzer
# =============================================

# %%
#------challenges-------

# %%
# Challenge 1: Daily Water Intake Calculator

# Water Intake (ml) = Weight × 35

water_intake = weight * 35

print("===== Daily Water Intake =====")
print(f"Recommended Water Intake : {water_intake:.0f} ml/day")
# Out:
# ===== Daily Water Intake =====
# Recommended Water Intake : 2100 ml/day

# %%
# Challenge 2: Weight Difference Calculator

# Ideal Weight = 22 × Height²

ideal_weight = 22 * (height ** 2)
weight_difference = weight - ideal_weight

print("===== Weight Difference Calculator =====")
print(f"Current Weight    : {weight:.1f} kg")
print(f"Ideal Weight      : {ideal_weight:.1f} kg")
print(f"Weight Difference : {weight_difference:.1f} kg")
# Out:
# ===== Weight Difference Calculator =====
# Current Weight    : 60.0 kg
# Ideal Weight      : 88.0 kg
# Weight Difference : -28.0 kg
